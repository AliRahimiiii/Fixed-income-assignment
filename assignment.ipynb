# ..        ...       ...       ...       ...       ...       ...       ...
# 116  0.043339  0.039793  0.038635  0.037508  0.042340  0.041279  0.045358
# 117  0.043327  0.039793  0.038640  0.037516  0.042337  0.041275  0.045362
# 118  0.043314  0.039793  0.038642  0.037522  0.042332  0.041269  0.045366
# 119  0.043300  0.039791  0.038641  0.037527  0.042327  0.041263  0.045369
# 120  0.043286  0.039789  0.038639  0.037531  0.042321  0.041257  0.045372
#
# [120 rows x 636 columns]

# %%
lamba = 0.0609

# %%
tau = np.arange(1, 121)
B = np.stack([np.ones_like(tau),
                (1 - np.exp(-lamba * tau))/(lamba * tau),
                    (1 - np.exp(-lamba * tau))/(lamba * tau) - np.exp(-lamba * tau)], axis=1)

# %%
B.shape
# Out:
# (120, 3)

# %%
y = np.asarray(data.T)

# %%
y.shape
# Out:
# (120, 636)

# %%
i = 25


# estimate the beta parameters using data up to time i
y_slice = y[:, :i]

# %%
model = LinearRegression(fit_intercept=False)
model.fit(B, y_slice)
# Out:
# LinearRegression(fit_intercept=False)

# %%
B[12-1, :].reshape(-1, 1)
# Out:
# array([[1.        ],
#        [0.70946413],
#        [0.22794051]])

# %%
model.coef_[:,0]
# Out:
# array([0.06495578, 0.06451958, 0.06044101, 0.06397247, 0.0644753 ,
#        0.06062372, 0.06346521, 0.06454719, 0.06540123, 0.0640006 ,
#        0.06352071, 0.06319276, 0.06284267, 0.06221369, 0.06262618,
#        0.06466954, 0.06773546, 0.06675643, 0.06669619, 0.06787071,
#        0.06746337, 0.06614309, 0.06721012, 0.06801068, 0.07157938])

# %%
beta = {
        1 : [],
        2 : [],
        3: []
    }
# estimate beta parameters for each time t in the sample up to i
for t in range(i):    
    model = LinearRegression(fit_intercept=False)
    model.fit(B, y_slice[:,t])
    beta[1].append(model.coef_[0].item())
    beta[2].append(model.coef_[1].item())
    beta[3].append(model.coef_[2].item())

# %%
beta = {k: np.array(v).reshape(-1, 1) for k, v in beta.items()}

# %%
ar_beta1 = LinearRegression(fit_intercept=True)
ar_beta1.fit(beta[1][0:i-1], beta[1][1:i])
ar_beta2 = LinearRegression(fit_intercept=True)
ar_beta2.fit(beta[2][0:i-1], beta[2][1:i])
ar_beta3 = LinearRegression(fit_intercept=True)
ar_beta3.fit(beta[3][0:i-1], beta[3][1:i])
# Out:
# LinearRegression()

# %%
def recursive_forecast(model, last_known_value, h):
    # Ensure input is 2D (1, 1) for sklearn
    current_val = last_known_value.reshape(1, -1)
    
    for _ in range(h):
        current_val = model.predict(current_val)
        
    return current_val[0, 0].item()

# %%
print(funcs.getNelsonSiegelForecast(120, 1, 12))
# Out:
# 0.12679953620237164

# %%
j = 25

# %%
data = pd.read_excel('LW_monthly_1972-2024.xlsx')           # Load the data
data = data.iloc[:, 2:]                                     # Remove year and month columns                  
data.index = range(1, len(data)+1)                          # Reset index to start from 1


y = data[j - 1].shift(-1) - data[j]                             # shape (635,)
X = (data[j] - data[1]) / (j - 1)                               # shape (635,)

# %%
# fit the regression model
valid_idx = ~np.isnan(y) & ~np.isnan(X)
y_clean = y[valid_idx].values.reshape(-1, 1)
X_clean = X[valid_idx].values.reshape(-1, 1)
model = LinearRegression(fit_intercept=True)
model.fit(X_clean, y_clean)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([[-1.05517251]]), array([0.00016422]))

# %%
funcs.getEHtest(60)
# Out:
# -0.15333817871809247
